# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_json('train.json')

# %%
train.head()
# Out:
#        cuisine     id                                        ingredients
# 0        greek  10259  [romaine lettuce, black olives, grape tomatoes...
# 1  southern_us  25693  [plain flour, ground pepper, salt, tomatoes, g...
# 2     filipino  20130  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3       indian  22213                [water, vegetable oil, wheat, salt]
# 4       indian  13162  [black pepper, shallots, cornflour, cayenne pe...

# %%
fig, axes = plt.subplots(nrows=1, sharey=False, figsize=(10,5))
g = sns.countplot(train.cuisine, color = 'green')
g.set_xlabel("Cuisine",fontsize=12)
g.set_ylabel("Total",fontsize=12)
g.set_title("Distribution of Recipes by Cuisine",fontsize=20)
g.tick_params(labelsize=15)
g.set_xticklabels(g.get_xticklabels(),rotation=45,ha="right",rotation_mode='anchor')
# Out:
# [Text(0,0,'greek'),
#  Text(0,0,'southern_us'),
#  Text(0,0,'filipino'),
#  Text(0,0,'indian'),
#  Text(0,0,'jamaican'),
#  Text(0,0,'spanish'),
#  Text(0,0,'italian'),
#  Text(0,0,'mexican'),
#  Text(0,0,'chinese'),
#  Text(0,0,'british'),
#  Text(0,0,'thai'),
#  Text(0,0,'vietnamese'),
#  Text(0,0,'cajun_creole'),
#  Text(0,0,'brazilian'),
#  Text(0,0,'french'),
#  Text(0,0,'japanese'),
#  Text(0,0,'irish'),
#  Text(0,0,'korean'),
#  Text(0,0,'moroccan'),
#  Text(0,0,'russian')]

# %%
train['count_ingredients'] = train.ingredients.apply(len)

# %%
fig, axes = plt.subplots(nrows=1, sharey=False, figsize=(10,5))
g = sns.distplot(train[train.count_ingredients <= 30].count_ingredients)
g.set_xlabel("Total Ingredients per Recipe",fontsize=12)
g.set_title("Distribution of Ingredients per Recipe",fontsize=20)
# Out:
# Text(0.5,1,'Distribution of Ingredients per Recipe')

# %%
np.average(train.count_ingredients)
# Out:
# 10.767712576054709

# %%
train[train.count_ingredients >30]
# Out:
#             cuisine     id                                        ingredients  \
# 294        filipino   9829  [sugar, fresh cilantro, hoisin sauce, butter, ...
# 345            thai  45039  [fish sauce, hot red pepper flakes, cider vine...
# 1392       japanese   2069  [tomatoes, sugar, whole wheat flour, bay leave...
# 3359         indian  21624  [red chili peppers, fresh coriander, fresh gin...
# 4123        chinese  40469  [eggs, pork, pepper, egg noodles, napa cabbage...
# 6139        mexican  36645  [rub, pepper, olive oil, chipotle, chili powde...
# 6380        mexican  27695  [clove, pasilla chiles, sesame seeds, Mexican ...
# 6449    southern_us   6548  [canned black beans, seasoned bread crumbs, pr...
# 7455           thai  22567  [red chili powder, water, thai basil, shallots...
# 10379       chinese   9077  [low sodium soy sauce, water, ground black pep...
# 10513       mexican  49282  [condensed cream of chicken soup, pepper, refr...
# 10893  cajun_creole  33586  [celery salt, andouille sausage, schmaltz, oni...
# 11120  cajun_creole  41498  [granulated garlic, fresh cilantro, chili powd...
# 13633      jamaican  40817  [tomatoes, sugar, lime juice, cooking oil, pap...
# 13940      jamaican  37435  [veggie patties, bread crumbs, vegetables, flo...
# 15289       italian   3885  [fettucine, fresh marjoram, minced garlic, oli...
# 18195     brazilian   8102  [manioc flour, sausage links, orange, kale, la...
# 18353       mexican  11929  [tomato paste, water, garlic powder, lemon, Br...
# 19749       mexican   2660  [avocado, black beans, fresh cilantro, Mexican...
# 20080        indian  29048  [fresh coriander, almonds, yoghurt, raisins, g...
# 20486      moroccan  44653  [capers, water, olive oil, large eggs, kalamat...
# 20887      moroccan  43737  [clove, fresh coriander, almonds, granulated s...
# 21896        indian  21298  [tomato paste, black pepper, garam masala, rai...
# 22167       mexican   3934  [grilled chicken breasts, kosher salt, nonfat ...
# 22658          thai  20439  [clove, chili flakes, lime juice, ground nutme...
# 22906        indian   2253  [white vinegar, sparkling lemonade, coconut su...
# 23889    vietnamese  39930  [clove, water, thai basil, mushrooms, star ani...
# 24734       mexican  32389  [fresh tomatoes, minced garlic, refried beans,...
# 25223   southern_us  25602  [mayonaise, pepper, olive oil, prepared horser...
# 26103       mexican  13049  [vanilla ice cream, lime, garlic powder, zucch...
# 27552       mexican  27148  [diced onions, cheddar cheese, black beans, ol...
# 28480       mexican  42951  [lime zest, refried black beans, boneless chic...
# 29163       mexican  28811  [pepper, honey, jalapeno chilies, tomatillos, ...
# 30350     brazilian  13430  [marshmallows, fresh corn, cheddar cheese, shr...
# 31250       italian  29216  [eggs, warm water, pepper, dried basil, unsalt...
# 32697       mexican   4740  [chicken broth, sugar, peanuts, tomatillos, ch...
# 33822       spanish  37986  [saffron threads, chicken legs, lime, lobster,...
# 35676        indian  40455  [chili flakes, pepper, fennel, potatoes, veget...
# 36203        french  12198  [diced potatoes, white wine, dried thyme, lobs...
# 37941       italian  19962  [frozen spinach, fresh basil, yellow squash, z...
#
#        count ingredients  count_ingredients
# 294                   38                 38
# 345                   40                 40
# 1392                  34                 34
# 3359                  40                 40
# 4123                  32                 32
# 6139                  36                 36
# 6380                  34                 34
# 6449                  40                 40
# 7455                  32                 32
# 10379                 38                 38
# 10513                 49                 49
# 10893                 31                 31
# 11120                 31                 31
# 13633                 32                 32
# 13940                 35                 35
# 15289                 65                 65
# 18195                 36                 36
# 18353                 31                 31
# 19749                 33                 33
# 20080                 34                 34
# 20486                 31                 31
# 20887                 31                 31
# 21896                 33                 33
# 22167                 31                 31
# 22658                 31                 31
# 22906                 49                 49
# 23889                 31                 31
# 24734                 31                 31
# 25223                 33                 33
# 26103                 52                 52
# 27552                 36                 36
# 28480                 36                 36
# 29163                 32                 32
# 30350                 59                 59
# 31250                 43                 43
# 32697                 31                 31
# 33822                 35                 35
# 35676                 33                 33
# 36203                 31                 31
# 37941                 35                 35
